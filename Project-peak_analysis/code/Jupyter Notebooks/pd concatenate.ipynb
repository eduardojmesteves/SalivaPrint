# %%
#import packages
import numpy as np
import pandas as pd
from pandas_profiling import ProfileReport
import pandas_profiling as pp

# %%
#import profiles dataset 
samples = pd.read_csv("Samples.csv",header=0, index_col='Sample')
samples.head(2)
# Out:
#               9.0        9.1        9.2        9.3        9.4        9.5  \
# Sample
# D1406  -62.244672 -52.457014 -42.210655 -32.204871 -23.491503 -16.696638
# D1406  -81.605963 -73.379503 -63.529882 -53.410731 -43.921040 -36.125306
#
#               9.6        9.7        9.9       10.0  ...     116.8     117.2  \
# Sample                                              ...
# D1406  -12.193077  -9.994839  -9.813816 -11.251397  ... -0.181758 -0.462081
# D1406  -30.061558 -25.768962 -23.334017 -22.874460  ... -0.506436 -0.942482
#
#            117.7     118.1     118.6     119.0     119.5     119.9     120.3  \
# Sample
# D1406  -0.843100 -1.052588 -1.271526 -1.538121 -1.750944 -1.938444 -2.147266
# D1406  -1.277635 -1.309136 -1.309286 -1.428850 -1.641247 -1.864567 -2.057687
#
#            120.8
# Sample
# D1406  -2.379568
# D1406  -2.290072
#
# [2 rows x 403 columns]

# %%
#import metadata dataset
metadata = pd.read_csv("good_dataset.csv",header=0, index_col='Sample')
metadata.head(2)
# Out:
#         Age Age group  Gender  Height  Weight            BMI      BMI group  \
# Sample
# D1122    10       <13    Male   138.0    31.0  1.627.809.284    Underweight
# D1127     7       <13  Female   126.0    32.0  2.015.621.063  Normal weight
#
#        Smoke habits Alcool habits Menopause  ... IL-31 IL-33 IFN-g sCD40L  \
# Sample                                       ...
# D1122            No            No       Man  ...   NaN   NaN   NaN    NaN
# D1127            No            No        No  ...   NaN   NaN   NaN    NaN
#
#        TNF-a C-Peptide Glucagon Insulin GLP-1 Active Leptin
# Sample
# D1122    NaN       NaN      NaN     NaN          NaN    NaN
# D1127    NaN     11.64    12.05   57.57          NaN    NaN
#
# [2 rows x 67 columns]

# %%
dir(pp)
# Out:
# ['DEFAULT_OUTPUTFILE',
#  'NO_OUTPUTFILE',
#  'ProfileReport',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'base',
#  'codecs',
#  'describe',
#  'formatters',
#  'plot',
#  'report',
#  'templates',
#  'to_html']

# %%
pp.ProfileReport(metadata)
# Out:
# /home/ee/anaconda3/lib/python3.7/site-packages/pandas_profiling/describe.py:392: FutureWarning: The join_axes-keyword is deprecated. Use .reindex or .reindex_like on the result to achieve the same functionality.
#   variable_stats = pd.concat(ldesc, join_axes=pd.Index([names]), axis=1)
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
# ...

# %%
pp.ProfileReport(samples)
# Out:
# /home/ee/anaconda3/lib/python3.7/site-packages/pandas_profiling/describe.py:392: FutureWarning: The join_axes-keyword is deprecated. Use .reindex or .reindex_like on the result to achieve the same functionality.
#   variable_stats = pd.concat(ldesc, join_axes=pd.Index([names]), axis=1)
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
# ...

# %%
profile = pp.ProfileReport(metadata)
profile.to_file('profile.html')
# Out:
# /home/ee/anaconda3/lib/python3.7/site-packages/pandas_profiling/describe.py:392: FutureWarning: The join_axes-keyword is deprecated. Use .reindex or .reindex_like on the result to achieve the same functionality.
#   variable_stats = pd.concat(ldesc, join_axes=pd.Index([names]), axis=1)

# %%
kw1 = metadata[['Sample','Age group','Gender']]
kw1.head()
# Out:
#   Sample Age group  Gender
# 0  D1122       <13    Male
# 1  D1127       <13  Female
# 2  D1132       <13  Female
# 3  D1138     13-24  Female
# 4  D1143     13-24  Female

# %%
kruskal = kw1.merge(samples, how='inner', on='Sample')

kruskal.head()
# Out:
#   Sample Age group  Gender         9.0         9.1         9.2         9.3  \
# 0  D1122       <13    Male  -66.899189  -57.956380  -49.865632  -42.760716
# 1  D1122       <13    Male  -69.882155  -60.823732  -52.619868  -45.468589
# 2  D1138     13-24  Female -101.624743 -103.154567 -101.005651  -97.943508
# 3  D1138     13-24  Female -112.338401 -114.021760 -107.965437 -100.954144
# 4  D1143     13-24  Female   64.030962   14.903387  -21.367195  -45.827966
#
#          9.4        9.5        9.6  ...     116.8     117.2     117.7  \
# 0 -36.760620 -31.847161 -27.881861  ... -0.797122 -0.966253 -1.078960
# 1 -39.379809 -34.363317 -30.345212  ... -0.413701 -0.390115 -0.446808
# 2 -93.704260 -87.971012 -81.504261  ...  0.638402  0.096138 -0.086788
# 3 -94.979890 -88.949258 -82.420227  ...  1.661894  1.114958  0.608922
# 4 -60.419500 -67.417181 -68.962492  ... -0.619201 -0.463723 -0.416500
#
#       118.1     118.6     119.0     119.5     119.9     120.3     120.8
# ...

# %%
def select_column(self):
    result = input('Select variable to analyze: Gender or Age group')
    if not result:
        print("Select a variable please!")
    else:
        print("Result is:", result)

# %%
kruskal.set_index(keys = ['Sample', 'Gender','Age group'], inplace=True)
kruskal.head()
# Out:
#                                9.0        9.1        9.2        9.3  \
# Sample Gender Age group
# D1406  Female 13-24     -62.244672 -52.457014 -42.210655 -32.204871
#               13-24     -81.605963 -73.379503 -63.529882 -53.410731
# D1202  Male   13-24     -54.015308 -65.326773 -64.685859 -59.112713
#               13-24     -36.074493 -51.368412 -55.463124 -53.807609
# D1411  Female 13-24     -23.297790 -41.467826 -49.469903 -50.065570
#
#                                9.4        9.5        9.6        9.7  \
# Sample Gender Age group
# D1406  Female 13-24     -23.491503 -16.696638 -12.193077  -9.994839
#               13-24     -43.921040 -36.125306 -30.061558 -25.768962
# D1202  Male   13-24     -51.891025 -44.463955 -37.754285 -32.256899
#               13-24     -49.615077 -44.110845 -38.377580 -33.187815
# D1411  Female 13-24     -46.380969 -40.225806 -32.841653 -25.568844
#
#                                9.9       10.0  ...  IL-31  IL-33  IFN-g  \
# ...

# %%
kruskal.index
# Out:
# MultiIndex([('D1406', 'Female', '13-24'),
#             ('D1406', 'Female', '13-24'),
#             ('D1202',   'Male', '13-24'),
#             ('D1202',   'Male', '13-24'),
#             ('D1411', 'Female', '13-24'),
#             ('D1411', 'Female', '13-24'),
#             ('D1388', 'Female', '13-24'),
#             ('D1388', 'Female', '13-24'),
#             ('D1401', 'Female', '13-24'),
#             ('D1401', 'Female', '13-24'),
#             ('D1167', 'Female',   '<13'),
#             ('D1167', 'Female',   '<13'),
#             ('D1183', 'Female',   '<13'),
#             ('D1183', 'Female',   '<13'),
#             ('D1143', 'Female', '13-24'),
#             ('D1143', 'Female', '13-24'),
#             ('D1165', 'Female',   '<13'),
#             ('D1165', 'Female',   '<13'),
#             ('D1402', 'Female', '13-24'),
#             ('D1402', 'Female', '13-24'),
#             ('D1122',   'Male',   '<13'),
#             ('D1122',   'Male',   '<13'),
# ...

# %%
kruskal.index.names
# Out:
# FrozenList(['Sample', 'Gender', 'Age group'])
