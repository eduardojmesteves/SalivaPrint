# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")

# %%
sp1 = pd.read_csv('Samples.csv', index_col='Sample', header=0)
sp = sp1.T
sp.head()
# Out:
# Sample      D1406      D1261
# 9.0    -62.244672 -10.410634
# 9.1    -52.457014  -5.997571
# 9.2    -42.210655  -0.689525
# 9.3    -32.204871   3.752646
# 9.4    -23.491503   8.068268

# %%
sp.to_csv('t1.csv', index_label=0)

# %%
df = pd.read_csv('t1.csv')
df.head()
# Out:
#      0      D1406      D1261
# 0  9.0 -62.244672 -10.410634
# 1  9.1 -52.457014  -5.997571
# 2  9.2 -42.210655  -0.689525
# 3  9.3 -32.204871   3.752646
# 4  9.4 -23.491503   8.068268

# %%
sns.lineplot(x = df.index, y = 'D1406', data = sp)

# %%
ax = sns.lineplot(x="timepoint", y="signal", hue="event",
                  units="subject", estimator=None, lw=1,
                  data=fmri.query("region == 'frontal'"))
